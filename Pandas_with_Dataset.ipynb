# %%
import pandas as pd

# %%
dataset= { 'cars':["BMW","Ford","Maruti"],
    'color_code':[1,3,5]
}

df=pd.DataFrame(dataset)
print(df)
# Out:
#      cars  color_code
# 0     BMW           1
# 1    Ford           3
# 2  Maruti           5

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
a=[1,7,2]
df1=pd.Series(a)
print(df1)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
b=[1,3,4]
mydf=pd.Series(b,index=["x","y","z"])
print(mydf)
# Out:
# x    1
# y    3
# z    4
# dtype: int64

# %%
print(mydf['y'])
# Out:
# 3

# %%
import pandas as pd
dict1={'A':1,'B':2,'C':3}
v1=pd.Series(dict1)
print(v1)
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
import pandas as pd
df3=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/Mall_Customers.csv")
df3
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 245         246    Male   30                 297                      69
# 246         247  Female   56                 311                      14
# 247         248    Male   29                 313                      90
# 248         249  Female   19                 316                      32
# 249         250  Female   31                 325                      86
#
# [250 rows x 5 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(df3.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print(df3.tail())
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 245         246    Male   30                 297                      69
# 246         247  Female   56                 311                      14
# 247         248    Male   29                 313                      90
# 248         249  Female   19                 316                      32
# 249         250  Female   31                 325                      86

# %%
df3.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df3.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              250 non-null    int64
#  1   Gender                  250 non-null    object
#  2   Age                     250 non-null    int64
#  3   Annual Income (k$)      250 non-null    int64
#  4   Spending Score (1-100)  250 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 9.9+ KB
# None

# %%
import pandas as pd
pd.read_csv("/Health_data.csv")
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df4=pd.read_csv("/Health_data.csv")

# %%
df4.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df4.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df4.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %% [markdown]
# ## **Advanced Pandas**

# %%
import pandas as pd
df5=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/SampleSuperstore.csv')

# %%
print(df5)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df5.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df5['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df5['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df5['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df5['Sub-Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
(df5['Sub-Category'].value_counts()).sort_values()
# Out:
# Copiers          68
# Machines        115
# Supplies        190
# Fasteners       217
# Bookcases       228
# Envelopes       254
# Tables          319
# Labels          364
# Appliances      466
# Chairs          617
# Accessories     775
# Art             796
# Storage         846
# Phones          889
# Furnishings     957
# Paper          1370
# Binders        1523
# Name: Sub-Category, dtype: int64

# %%
(df5['Sub-Category'].value_counts()).sort_values(ascending=False)
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
df5.sort_values('Category')
# Out:
#       Row ID    Category Sub-Category     Sales  Quantity  Discount   Profit
# 0          1   Furniture    Bookcases   261.960         2      0.00  41.9136
# 8133    8134   Furniture  Furnishings    72.780         3      0.60 -70.9605
# 1903    1904   Furniture       Chairs   478.480         2      0.20  47.8480
# 6151    6152   Furniture    Bookcases  1198.330        10      0.15  70.4900
# 6153    6154   Furniture  Furnishings    51.968         2      0.20  10.3936
# ...      ...         ...          ...       ...       ...       ...      ...
# 1844    1845  Technology  Accessories    90.570         3      0.00  11.7741
# 3921    3922  Technology       Phones   359.976         3      0.20  35.9976
# 6173    6174  Technology  Accessories    21.200         2      0.00   9.1160
# 8348    8349  Technology       Phones   209.500        10      0.00  58.6600
# 2522    2523  Technology       Phones     5.500         1      0.00   1.3750
#
# [9994 rows x 7 columns]

# %%
df5.sort_values(['Category','Profit'])
# Out:
#       Row ID    Category Sub-Category      Sales  Quantity  Discount  \
# 9639    9640   Furniture       Tables   4297.644        13       0.4
# 27        28   Furniture    Bookcases   3083.430         7       0.5
# 5320    5321   Furniture       Tables   2314.116         7       0.4
# 8993    8994   Furniture       Tables   1875.258         7       0.4
# 463      464   Furniture       Tables   1272.630         6       0.5
# ...      ...         ...          ...        ...       ...       ...
# 8488    8489  Technology     Machines   8749.950         5       0.0
# 2623    2624  Technology      Copiers  11199.968         4       0.2
# 4190    4191  Technology      Copiers  10499.970         3       0.0
# 8153    8154  Technology      Copiers  13999.960         4       0.0
# 6826    6827  Technology      Copiers  17499.950         5       0.0
#
#          Profit
# 9639 -1862.3124
# 27   -1665.0522
# 5320 -1002.7836
# 8993  -968.8833
# 463   -814.4832
# ...         ...
# 8488  2799.9840
# 2623  3919.9888
# 4190  5039.9856
# 8153  6719.9808
# 6826  8399.9760
#
# [9994 rows x 7 columns]

# %%
df5.shape
# Out:
# (9994, 7)

# %%
df5.drop_duplicates(subset=['Sub-Category'])
# Out:
#      Row ID         Category Sub-Category      Sales  Quantity  Discount  \
# 0         1        Furniture    Bookcases   261.9600         2      0.00
# 1         2        Furniture       Chairs   731.9400         3      0.00
# 2         3  Office Supplies       Labels    14.6200         2      0.00
# 3         4        Furniture       Tables   957.5775         5      0.45
# 4         5  Office Supplies      Storage    22.3680         2      0.20
# 5         6        Furniture  Furnishings    48.8600         7      0.00
# 6         7  Office Supplies          Art     7.2800         4      0.00
# 7         8       Technology       Phones   907.1520         6      0.20
# 8         9  Office Supplies      Binders    18.5040         3      0.20
# 9        10  Office Supplies   Appliances   114.9000         5      0.00
# 12       13  Office Supplies        Paper    15.5520         3      0.20
# 26       27       Technology  Accessories    90.5700         3      0.00
# 30       31  Office Supplies    Envelopes     3.2640         2      0.20
# 53       54  Office Supplies    Fasteners    15.2600         7      0.00
# 138     139  Office Supplies     Supplies    65.8800         6      0.00
# 165     166       Technology     Machines  8159.9520         8      0.40
# 335     336       Technology      Copiers   959.9840         2      0.20
#
#         Profit
# 0      41.9136
# 1     219.5820
# 2       6.8714
# 3    -383.0310
# 4       2.5164
# 5      14.1694
# 6       1.9656
# 7      90.7152
# 8       5.7825
# 9      34.4700
# 12      5.4432
# 26     11.7741
# 30      1.1016
# 53      6.2566
# 138    18.4464
# 165 -1359.9920
# 335   335.9944

# %%
df5.drop_duplicates(subset=['Sub-Category','Category']).shape
# Out:
# (17, 7)

# %%
df5.shape
# Out:
# (9994, 7)

# %%
categories=df5.groupby('Category')
categories

# %%
len(df5)
# Out:
# 9994

# %%
len(categories)
# Out:
# 3

# %%
categories.size()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64

# %%
categories.first()
# Out:
#                       Ship Mode    Segment        Country         City  \
# Category
# Furniture          Second Class   Consumer  United States    Henderson
# Office Supplies    Second Class  Corporate  United States  Los Angeles
# Technology       Standard Class   Consumer  United States  Los Angeles
#
#                       State  Postal Code Region Sub-Category    Sales  \
# Category
# Furniture          Kentucky        42420  South    Bookcases  261.960
# Office Supplies  California        90036   West       Labels   14.620
# Technology       California        90032   West       Phones  907.152
#
#                  Quantity  Discount   Profit
# Category
# Furniture               2       0.0  41.9136
# Office Supplies         2       0.0   6.8714
# Technology              6       0.2  90.7152

# %%
# Renaming & Combining

# %%
import pandas as pd
import numpy as np

df1=pd.read_csv('/content/Health_data.csv')

# %%
df1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df1.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#rename(), which lets  change column names.
df1.rename(columns={'Duration': 'Timing'})
# Out:
#      Timing  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# ..      ...    ...       ...       ...
# 164      60    105       140     290.8
# 165      60    110       145     300.0
# 166      60    115       145     310.2
# 167      75    120       150     320.4
# 168      75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#rename() lets you rename index values by specifying a index

df1.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              Duration  Pulse  Maxpulse  Calories
# firstEntry         60    110       130     409.1
# secondEntry        60    117       145     479.0
# 2                  60    103       135     340.0
# 3                  45    109       175     282.4
# 4                  45    117       148     406.0
# ...               ...    ...       ...       ...
# 164                60    105       140     290.8
# 165                60    110       145     300.0
# 166                60    115       145     310.2
# 167                75    120       150     320.4
# 168                75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df2=pd.read_csv('/content/sales.csv')

# %%
df2.head()
# Out:
#    USERID   ORDERDATE     ORDERID  AMOUNTINFO
# 0  142074  2016-01-01  4196439032      9399.0
# 1   56927  2016-01-01  4198324983      8799.0
# 2   87058  2016-01-01  4191287379      6899.0
# 3  136104  2016-01-01  4198508313      5999.0
# 4  117831  2016-01-01  4202238313      5399.0

# %%
pd.concat([df1, df2])
# Out:
#        Duration  Pulse  Maxpulse  Calories    USERID   ORDERDATE  \
# 0          60.0  110.0     130.0     409.1       NaN         NaN
# 1          60.0  117.0     145.0     479.0       NaN         NaN
# 2          60.0  103.0     135.0     340.0       NaN         NaN
# 3          45.0  109.0     175.0     282.4       NaN         NaN
# 4          45.0  117.0     148.0     406.0       NaN         NaN
# ...         ...    ...       ...       ...       ...         ...
# 86130       NaN    NaN       NaN       NaN  110416.0  2016-12-29
# 86131       NaN    NaN       NaN       NaN  149172.0  2016-12-29
# 86132       NaN    NaN       NaN       NaN   58525.0  2016-12-29
# 86133       NaN    NaN       NaN       NaN  161732.0  2016-12-29
# 86134       NaN    NaN       NaN       NaN   61176.0  2016-12-29
#
#             ORDERID  AMOUNTINFO
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 86130  4.111877e+09         3.9
# 86131  4.182928e+09         0.5
# 86132  4.080138e+09         0.5
# 86133  4.193916e+09         0.5
# 86134  4.195480e+09         0.5
#
# [86304 rows x 8 columns]

# %%
#join() lets you combine different DataFrame objects which have an index in common.

df1.join(df2)
# Out:
#      Duration  Pulse  Maxpulse  Calories  USERID   ORDERDATE     ORDERID  \
# 0          60    110       130     409.1  142074  2016-01-01  4196439032
# 1          60    117       145     479.0   56927  2016-01-01  4198324983
# 2          60    103       135     340.0   87058  2016-01-01  4191287379
# 3          45    109       175     282.4  136104  2016-01-01  4198508313
# 4          45    117       148     406.0  117831  2016-01-01  4202238313
# ..        ...    ...       ...       ...     ...         ...         ...
# 164        60    105       140     290.8  119463  2016-01-01  4193575550
# 165        60    110       145     300.0  123776  2016-01-01  4167362296
# 166        60    115       145     310.2   57709  2016-01-01  4116037489
# 167        75    120       150     320.4   92343  2016-01-01  3906386793
# 168        75    125       150     330.4  150087  2016-01-01  4196654014
#
#      AMOUNTINFO
# 0        9399.0
# 1        8799.0
# 2        6899.0
# 3        5999.0
# 4        5399.0
# ..          ...
# 164        16.9
# 165        16.9
# 166        16.5
# 167        16.0
# 168        16.0
#
# [169 rows x 8 columns]

# %%
import pandas as pd
df3=pd.read_csv('/content/Superstore_data.csv')

# %%
df3.head()
# Out:
#    Row ID         Category Sub-Category     Sales  Quantity  Discount  \
# 0       1        Furniture    Bookcases  261.9600         2      0.00
# 1       2        Furniture       Chairs  731.9400         3      0.00
# 2       3  Office Supplies       Labels   14.6200         2      0.00
# 3       4        Furniture       Tables  957.5775         5      0.45
# 4       5  Office Supplies      Storage   22.3680         2      0.20
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
# Tuples are used to store multiple items in a single variable.
# A tuple is a collection which is ordered and unchangeable.
# Tuple items are ordered, unchangeable, and allow duplicate values.
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc.

# %%
t1=(1,2,3,4,5)

# %%
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %%
print(len(t1))
# Out:
# 5

# %%
t2=("A","B","C","D","E")

# %%
print(t2)
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %%
t2[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-562e8f678842> in <cell line: 1>()
# ----> 1 t2[3]
#
# IndexError: tuple index out of range

# %%
# Access Elements in Tuple
t1[3]
# Out:
# 4

# %%
t1[1:3]
# Out:
# (2, 3)

# %%
t1[2:]
# Out:
# (3, 4, 5)

# %%
t1[2:6]
# Out:
# (3, 4, 5)

# %%
t1[0:3]
# Out:
# (1, 2, 3)

# %%
t1[:3]
# Out:
# (1, 2, 3)

# %%
t2[-3:-1]
# Out:
# ('C', 'D')

# %%
t2[-4:]
# Out:
# ('B', 'C', 'D', 'E')

# %%
t2[::-1]
# Out:
# ('E', 'D', 'C', 'B', 'A')

# %%
t2.reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-906fb4bed252> in <cell line: 1>()
# ----> 1 t2.reverse()
#
# AttributeError: 'tuple' object has no attribute 'reverse'

# %%
t2=("A","B","C","D","E")
y=list(t2)

# %%
print(type(y))
# Out:
# <class 'list'>

# %%
y[2]=11

# %%
t2=tuple(y)

# %%
t2
# Out:
# ('A', 'B', 11, 'D', 'E')

# %%
z=list(t2)

# %%
z.append(6)

# %%
z
# Out:
# ['A', 'B', 11, 'D', 'E', 6]

# %%
t2=tuple(z)

# %%
t2
# Out:
# ('A', 'B', 11, 'D', 'E', 6)

# %%
# Addition of Tuples

tuple_add1=(7,)

# %%
tuple_add2=(5,6,8,9)

# %%
tuple_add1=tuple_add1+tuple_add2

# %%
tuple_add1
# Out:
# (7, 5, 6, 8, 9)

# %%
# Remove items in tuple
h=list(t2)

# %%
t2
# Out:
# ('A', 'B', 11, 'D', 'E', 6)

# %%
h.remove(11)

# %%
h
# Out:
# ['A', 'B', 'D', 'E', 6]

# %%
t2=tuple(h)

# %%
t2
# Out:
# ('A', 'B', 'D', 'E', 6)

# %%
t11=(1,2,3)
t12=t11*2

# %%
t12
# Out:
# (1, 2, 3, 1, 2, 3)

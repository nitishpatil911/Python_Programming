# %%
print("Hello World")
# Out:
# Hello World

# %%
Str='Hello World! Hello India'
Pos=Str.index('Hello')
print(Pos)
# Out:
# 0

# %%
L=['Hello','World!']
print(*L)
# Out:
# Hello World!

# %%
Str='Hello World!'
print(Str.find('l'))
# Out:
# 2

# %%
S='INDIAN'
L=S.partition('N')
NS=L[0]+'-'+L[1]+'-'+L[2]
print(NS)
# Out:
# I-N-DIAN

# %%
S='INDIAN'
L=S.partition('N')
print(L)
# Out:
# ('I', 'N', 'DIAN')

# %%
D={'A':1,'B':2,'C':'3'}
print(D)
# Out:
# {'A': 1, 'B': 2, 'C': '3'}

# %%
D={'A':1,'B':2,'C':'3'}
del(D)
print(D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-46acc79330c2> in <cell line: 3>()
#       1 D={'A':1,'B':2,'C':'3'}
#       2 del(D)
# ----> 3 print(D)
#
# NameError: name 'D' is not defined

# %%
print(D)
# Out:
# {'A': 1, 'B': 2, 'C': '3'}

# %%
D1={'A':5,'B':7,'C':9}
D2={'B':5,'D':10}
D1.update(D2)
print(D1)
# Out:
# {'A': 5, 'B': 5, 'C': 9, 'D': 10}

# %%
D1={1:2,2:3,3:4}
D2=D1.get(1,2)
print(D2)
# Out:
# 2

# %%
  N=int(input("Enter the no"))
  for i in range(2,N):
      if(N%i==0):
        print(i)
# Out:
# Enter the no20
# 2
# 4
# 5
# 10

# %%
import random

# random integer from 0 to 9
num1 = random.randint(0, 9)
print(num1)
# Out:
# 5

# %%
import random

num1 = random.randint(0, 7)
print(num1)
# Out:
# 7

# %%
from math import*
A=5.6
print(floor(A),ceil(A))
# Out:
# 5 6

# %%
import math
print(math.fabs(-10))
# Out:
# 10.0
